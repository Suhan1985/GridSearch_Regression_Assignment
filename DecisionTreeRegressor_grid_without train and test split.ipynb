# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_features':['sqrt','log2']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print(" best parameter {}:".format(grid.best_params_))
# Out:
#  best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018745  6.248856e-03         0.003124        0.006249
# 1        0.009373  1.249683e-02         0.009372        0.007652
# 2        0.015622  9.879931e-03         0.006248        0.007653
# 3        0.006248  7.652436e-03         0.006248        0.007652
# 4        0.012496  6.248188e-03         0.006249        0.007653
# 5        0.012497  6.248569e-03         0.003124        0.006249
# 6        0.012497  1.169008e-02         0.006249        0.007653
# 7        0.015621  4.768372e-07         0.000000        0.000000
# 8        0.046863  0.000000e+00         0.006249        0.007653
# 9        0.031243  9.880157e-03         0.003124        0.006248
# 10       0.034367  6.249047e-03         0.003124        0.006248
# 11       0.028118  6.248999e-03         0.006249        0.007653
# 12       0.015621  3.873843e-07         0.006248        0.007653
# 13       0.012497  6.248737e-03         0.003124        0.006248
# 14       0.015621  9.879931e-03         0.009372        0.007652
# 15       0.006249  7.652845e-03         0.003125        0.006249
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.702316
# 1   {'criterion': 'squared_error', 'max_features':...           0.699928
# 2   {'criterion': 'squared_error', 'max_features':...           0.647144
# 3   {'criterion': 'squared_error', 'max_features':...           0.701555
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.732979
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.673868
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.694382
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.714228
# 8   {'criterion': 'absolute_error', 'max_features'...           0.765115
# 9   {'criterion': 'absolute_error', 'max_features'...           0.638447
# 10  {'criterion': 'absolute_error', 'max_features'...           0.642703
# 11  {'criterion': 'absolute_error', 'max_features'...           0.795614
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.690543
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.637687
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.629895
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.760769
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.597881           0.659254           0.633222
# 1            0.543750           0.701164           0.721388
# 2            0.627566           0.719263           0.450757
# 3            0.563338           0.690060           0.756024
# 4            0.623106           0.671536           0.728808
# 5            0.542418           0.693355           0.685027
# 6            0.590723           0.748464           0.678278
# 7            0.594438           0.674224           0.702317
# 8            0.640463           0.733423           0.756196
# 9            0.566580           0.759221           0.695913
# 10           0.617134           0.644780           0.696418
# 11           0.541110           0.628261           0.741028
# 12           0.631783           0.764702           0.736321
# 13           0.503640           0.690116           0.666267
# 14           0.673143           0.754553           0.673322
# 15           0.572286           0.660252           0.698068
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.719301         0.662395        0.044396               11
# 1            0.628430         0.658932        0.065669               12
# 2            0.679779         0.624902        0.092460               16
# 3            0.686188         0.679433        0.063233                8
# 4            0.717712         0.694828        0.042001                3
# 5            0.631222         0.645178        0.055654               15
# 6            0.709822         0.684334        0.052274                6
# 7            0.744199         0.685881        0.050936                5
# 8            0.692413         0.717522        0.046005                1
# 9            0.660305         0.664093        0.063628               10
# 10           0.666372         0.653482        0.026544               13
# 11           0.650238         0.671250        0.088951                9
# 12           0.721126         0.708895        0.045386                2
# 13           0.729176         0.645377        0.076953               14
# 14           0.742198         0.694622        0.046818                4
# 15           0.725151         0.683305        0.064539                7
